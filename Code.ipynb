# %% [markdown]
# <a href="https://colab.research.google.com/github/Rokon-Uz-Zaman/House-Price-Prediction/blob/main/Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Housing.csv")

# %%
data
# Out:
#         price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0    13300000  7420         4  ...        2       yes        furnished
# 1    12250000  8960         4  ...        3        no        furnished
# 2    12250000  9960         3  ...        2       yes   semi-furnished
# 3    12215000  7500         4  ...        3       yes        furnished
# 4    11410000  7420         4  ...        2        no        furnished
# ..        ...   ...       ...  ...      ...       ...              ...
# 540   1820000  3000         2  ...        2        no      unfurnished
# 541   1767150  2400         3  ...        0        no   semi-furnished
# 542   1750000  3620         2  ...        0        no      unfurnished
# 543   1750000  2910         3  ...        0        no        furnished
# 544   1750000  3850         3  ...        0        no      unfurnished
#
# [545 rows x 13 columns]

# %%
data.head()
# Out:
#       price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0  13300000  7420         4  ...        2       yes        furnished
# 1  12250000  8960         4  ...        3        no        furnished
# 2  12250000  9960         3  ...        2       yes   semi-furnished
# 3  12215000  7500         4  ...        3       yes        furnished
# 4  11410000  7420         4  ...        2        no        furnished
#
# [5 rows x 13 columns]

# %%
data.describe()
# Out:
#               price          area  ...     stories     parking
# count  5.450000e+02    545.000000  ...  545.000000  545.000000
# mean   4.766729e+06   5150.541284  ...    1.805505    0.693578
# std    1.870440e+06   2170.141023  ...    0.867492    0.861586
# min    1.750000e+06   1650.000000  ...    1.000000    0.000000
# 25%    3.430000e+06   3600.000000  ...    1.000000    0.000000
# 50%    4.340000e+06   4600.000000  ...    2.000000    0.000000
# 75%    5.740000e+06   6360.000000  ...    2.000000    1.000000
# max    1.330000e+07  16200.000000  ...    4.000000    3.000000
#
# [8 rows x 6 columns]

# %%
data.isnull().any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# prefarea            False
# furnishingstatus    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
features=['area', 'bedrooms', 'bathrooms', 'stories',
       'parking']

data[features]
# Out:
#      area  bedrooms  bathrooms  stories  parking
# 0    7420         4          2        3        2
# 1    8960         4          4        4        3
# 2    9960         3          2        2        2
# 3    7500         4          2        2        3
# 4    7420         4          1        2        2
# ..    ...       ...        ...      ...      ...
# 540  3000         2          1        1        2
# 541  2400         3          1        1        0
# 542  3620         2          1        1        0
# 543  2910         3          1        1        0
# 544  3850         3          1        2        0
#
# [545 rows x 5 columns]

# %%
x=data[features]

x
# Out:
#      area  bedrooms  bathrooms  stories  parking
# 0    7420         4          2        3        2
# 1    8960         4          4        4        3
# 2    9960         3          2        2        2
# 3    7500         4          2        2        3
# 4    7420         4          1        2        2
# ..    ...       ...        ...      ...      ...
# 540  3000         2          1        1        2
# 541  2400         3          1        1        0
# 542  3620         2          1        1        0
# 543  2910         3          1        1        0
# 544  3850         3          1        2        0
#
# [545 rows x 5 columns]

# %%
y=data['price']

y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.33, random_state=42)
print(xtrain.shape, xtest.shape,ytrain.shape, ytest.shape)
# Out:
# (365, 5) (180, 5) (365,) (180,)

# %%
#feature scaling 
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('std_scalar', StandardScaler())
])

xtrain= pipeline.fit_transform(xtrain)
xtest= pipeline.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# print the intercept
print(model.intercept_)
# Out:
# 4725939.150684931

# %%
prediction= model.predict(xtest)
print(prediction)
# Out:
# [6304787.34199317 6403553.09528829 3305582.39472979 4245879.73083088
#  3449597.39458945 4349763.96995937 5704639.09166934 5624088.30803902
#  3428569.52872649 3038651.78409448 9688308.64801035 3271010.77987863
#  3201215.25555647 3626199.84198926 3909948.00161674 6221784.44755373
#  3097331.01642798 4955932.02267752 4907009.92619003 3944831.12216641
#  5166580.94488547 4384009.43750062 3178058.79655239 4238407.94086092
#  6000484.29992185 7842743.61753175 2995742.45030899 4804948.37665192
#  7688097.63600734 3423478.32634462 5131095.68656856 4016627.7701176
#  6240479.44032997 4772607.63634625 4342603.37075261 5710689.05444855
#  4898233.5469804  3822398.41143557 3293046.68582946 4905585.78429266
#  5528519.54431435 3171861.99766397 6377461.31049496 4368866.86482757
#  4189441.60460389 4291229.163456   6697568.5742581  4682478.46584388
#  4613433.10749552 3734199.15627651 7946445.82024516 3350294.1743465
#  4906016.84264887 4082806.07587256 3972426.17399723 3107142.71917697
# ...

# %%
scr=model.score(xtest,prediction)
print(scr)
# Out:
# 1.0
